# %%
import pandas as pd

# %%
florida = pd.read_csv('../data/florida_covid_data_the_atlantic_ORIGINAL.csv')
new_york = pd.read_csv('../data/new_york_covid_data_the_atlantic.csv')

# %%
florida.head()
# Out:
#          date state dataQualityGrade    death  deathConfirmed  deathIncrease  \
# 0  2021-01-24    FL                A  25693.0             NaN            132
# 1  2021-01-23    FL                A  25561.0             NaN            156
# 2  2021-01-22    FL                A  25405.0             NaN            277
# 3  2021-01-21    FL                A  25128.0             NaN            163
# 4  2021-01-20    FL                A  24965.0             NaN            145
#
#    deathProbable  hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# 0            NaN       71219.0                 71219.0                 6727.0
# 1            NaN       71037.0                 71037.0                 6711.0
# 2            NaN       70767.0                 70767.0                 6904.0
# 3            NaN       70306.0                 70306.0                 7023.0
# 4            NaN       69954.0                 69954.0                 7141.0
#
# ...

# %%
new_york.head()
# Out:
#          date state dataQualityGrade    death  deathConfirmed  deathIncrease  \
# 0  2021-02-10    NY                A  36619.0             NaN            138
# 1  2021-02-09    NY                A  36481.0             NaN            142
# 2  2021-02-08    NY                A  36339.0             NaN            115
# 3  2021-02-07    NY                A  36224.0             NaN            145
# 4  2021-02-06    NY                A  36079.0             NaN            159
#
#    deathProbable  hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# 0            NaN       89995.0                 89995.0                 7593.0
# 1            NaN       89995.0                 89995.0                 7875.0
# 2            NaN       89995.0                 89995.0                 7716.0
# 3            NaN       89995.0                 89995.0                 7649.0
# 4            NaN       89995.0                 89995.0                 7804.0
#
# ...

# %%
new_york_new = new_york.iloc[::-1]

# %%
new_york_new.head()
# Out:
#            date state dataQualityGrade  death  deathConfirmed  deathIncrease  \
# 345  2020-03-02    NY              NaN    NaN             NaN              0
# 344  2020-03-03    NY              NaN    NaN             NaN              0
# 343  2020-03-04    NY              NaN    NaN             0.0              0
# 342  2020-03-05    NY              NaN    NaN             NaN              0
# 341  2020-03-06    NY              NaN    NaN             NaN              0
#
#      deathProbable  hospitalized  hospitalizedCumulative  \
# 345            NaN           NaN                     NaN
# 344            NaN           NaN                     NaN
# 343            NaN           NaN                     NaN
# 342            NaN           NaN                     NaN
# 341            NaN           NaN                     NaN
#
#      hospitalizedCurrently  ...  totalTestResults  totalTestResultsIncrease  \
# 345                    NaN  ...                 0                         0
# ...

# %%
new_york_new.to_csv('../data/new_york_covid_data_the_atlantic.csv', index=False)

# %%
florida_new = florida.iloc[::-1]

# %%
florida_new.head()
# Out:
#            date state dataQualityGrade  death  deathConfirmed  deathIncrease  \
# 361  2020-01-29    FL              NaN    NaN             NaN              0
# 360  2020-01-30    FL              NaN    NaN             NaN              0
# 359  2020-01-31    FL              NaN    NaN             NaN              0
# 358  2020-02-01    FL              NaN    NaN             NaN              0
# 357  2020-02-02    FL              NaN    NaN             NaN              0
#
#      deathProbable  hospitalized  hospitalizedCumulative  \
# 361            NaN           NaN                     NaN
# 360            NaN           NaN                     NaN
# 359            NaN           NaN                     NaN
# 358            NaN           NaN                     NaN
# 357            NaN           NaN                     NaN
#
#      hospitalizedCurrently  ...  totalTestResults  totalTestResultsIncrease  \
# 361                    NaN  ...                 1                         0
# ...

# %%
florida_new.to_csv('../data/florida_covid_data_the_atlantic.csv', index=False)
